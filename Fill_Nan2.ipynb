# %% [markdown]
# # 데이터 하나씩 결측값 처리

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DIRE = "/content/drive/My Drive/데이터 통합/DATA/1YR/"
for i in range(10, 20):
    FILN = DIRE + str(i) + ".csv"

    DATA = pd.read_csv(FILN, encoding = "CP949")
    print(f"step == {i - 9}\n\t")
    DATA.interpolate(method='linear',limit_direction='forward', inplace=True, axis = 0)
    print("INTERPOLATE DONE\n\t")
    DATA.to_csv(FILN, encoding = "CP949", index = False)
    print("SAVED\n\t")
    print("=====================================================================")
# Out:
# step == 1
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 2
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 3
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 4
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 5
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 6
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 7
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 8
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 9
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
# step == 10
#
# INTERPOLATE DONE
#
# SAVED
#
# ...
